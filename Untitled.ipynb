# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
# %matplotlib inline

# %%
import warnings    #to ignore any warning 
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv(r'C:\Users\acer\machine a to z\LOAN\train_u6lujuX_CVtuZ9i.csv')
test=pd.read_csv(r'C:\Users\acer\machine a to z\LOAN\test_Y3wMUE5_7gLdaTN.csv')

# %%
train_origional=train.copy()
test_origional=test.copy()

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#object means categorical values

# %%
test.shape
# Out:
# (367, 12)

# %%
train.shape
# Out:
# (614, 13)

# %%
train['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
train['Loan_Status'].value_counts(normalize=True)
# Out:
# Y    0.687296
# N    0.312704
# Name: Loan_Status, dtype: float64

# %%
train['Loan_Status'].value_counts().plot.bar()

# %%
train['Loan_Status'].value_counts(normalize=True).plot.bar()

# %% [raw]
#  Categorical features: These features have categories (Gender, Married, Self_Employed, Credit_History, Loan_Status)
#
# Ordinal features: Variables in categorical features having some order involved (Dependents, Education, Property_Area)
#
# Numerical features: These features have numerical values (ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term)

# %% [markdown]
# # Independent Variable (Categorical)

# %%
plt.subplot(221)
train['Gender'].value_counts(normalize=True).plot.bar(figsize=(15,10),title='Gender')

plt.subplot(222)
train['Married'].value_counts(normalize=True).plot.bar(title='Married')

plt.subplot(223)
train['Self_Employed'].value_counts(normalize=True).plot.bar(title='Self_Employed')

plt.subplot(224)
train['Credit_History'].value_counts(normalize=True).plot.bar(title='Credit_History')

# %% [markdown]
# --80% applicant in dataset are male
#
# --Arround 65% of the applicant in the dataset are married
#
# --arround 15% of the applicant in the dataset are self_employed
#
# --arround 85% applicant have repaid their debts

# %% [markdown]
# # Independent Variable (Ordinal)

# %%
plt.subplot(131)
train['Dependents'].value_counts(normalize=True).plot.bar(figsize=(25,5),title='Dependents')

plt.subplot(133)
train['Education'].value_counts(normalize=True).plot.bar(title='Education')

plt.subplot(132)
train['Property_Area'].value_counts(normalize=True).plot.bar(title='Property_Area')

# %% [markdown]
# --Around 60% of the applicants don't have any accounts
#
# --Most of the applicants are from semiurban area
#
# --Arround 80% of the applicants are Graduate

# %% [markdown]
# # Independent Variable (Numerical)

# %%
plt.subplot(121)
sea.distplot(train['ApplicantIncome'])

plt.subplot(122)
train['ApplicantIncome'].plot.box(figsize=(16,5))

# %% [markdown]
# --First Quartile is the the median of the lower half data
#
# --Third Quartile is the the median of the upper half data
#
#
# # ![title](boxplot1.png)

# %%
plt.figure(figsize=(20,6))
sea.distplot(train['ApplicantIncome'],
             rug=True,              #use rug to show all elements
            kde_kws={'linewidth':3})

# %%
train.boxplot(column='ApplicantIncome',by='Education')
plt.suptitle("")
# Out:
# Text(0.5,0.98,'')

# %% [markdown]
# ...Here Title Is ApplicantIncome And Subtitle Is 'boxplot group by Education' So We USe 'plt.suptitle("")' To Remove This...
#
#
#
#
#
#
#
# ...

# %%
plt.subplot(121)
sea.distplot(train['CoapplicantIncome'],rug=True)

plt.subplot(122)
train['CoapplicantIncome'].plot.box(figsize=(16,5))

# %%
plt.subplot(121)
df=train.dropna()
sea.distplot(df['LoanAmount'],rug=True)

plt.subplot(122)
train['LoanAmount'].plot.box(figsize=(15,6))

# %% [markdown]
# ---
#
#
#
# # BIVARIATE ANALYSIS...
#
#
#
# ---

# %% [markdown]
# Applicants with high income should have more chances of loan approval.
#
# Applicants who have repaid their previous debts should have higher chances of loan approval.
#
# Loan approval should also depend on the loan amount. If the loan amount is less, chances of loan approval should be high.
#
# Lesser the amount to be paid monthly to repay the loan, higher the chances of loan approval.

# %% [markdown]
# # Categorical Independent Variable vs Target Variable

# %%
df=pd.crosstab(train['Gender'],train['Loan_Status'])
df
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
df.plot.bar()

# %%
df=train['Gender'].groupby(train['Loan_Status']).value_counts()
df
# Out:
# Loan_Status  Gender
# N            Male      150
#              Female     37
# Y            Male      339
#              Female     75
# Name: Gender, dtype: int64

# %%
df.plot.bar()

# %%
gender=pd.crosstab(train['Gender'],train['Loan_Status'])
gender.div(gender.sum(1).astype(float),axis=0).plot.bar(figsize=(8,5))

# %%
gender=pd.crosstab(train['Gender'],train['Loan_Status'])
gender.div(gender.sum(1).astype(float),axis=0).plot.bar(figsize=(5,5),stacked=True)

# %%
Married=pd.crosstab(train['Married'],train['Loan_Status'])
Self_Employed=pd.crosstab(train['Self_Employed'],train['Loan_Status'])
Education=pd.crosstab(train['Education'],train['Loan_Status'])
Dependents=pd.crosstab(train['Dependents'],train['Loan_Status'])

Married.div(Married.sum(1).astype(float),axis=0).plot.bar(stacked=True)

Self_Employed.div(Self_Employed.sum(1).astype(float),axis=0).plot.bar(stacked=True)

Education.div(Education.sum(1).astype(float),axis=0).plot.bar(stacked=True)


Dependents.div(Dependents.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %% [markdown]
# #Married and graduate people having high priority to get loan
# #Distribution of applicants with 1 or 3+ dependents is similar across both the categories of Loan_Status.

# %%
Credit_History=pd.crosstab(train['Credit_History'],train['Loan_Status'])
Property_Area=pd.crosstab(train['Property_Area'],train['Loan_Status'])

Credit_History.div(Credit_History.sum(1).astype(float),axis=0).plot.bar(stacked=True)

Property_Area.div(Property_Area.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %% [markdown]
# It seems people with credit history as 1 are more likely to get their loans approved.
#
# Proportion of loans getting approved in semiurban area is higher as compared to that in rural or urban areas.

# %% [markdown]
# # Numerical Independent Variable vs Target Variable

# %%
train.groupby('Loan_Status')['ApplicantIncome'].mean().plot.bar()

# %% [markdown]
# It is same for both case so we make bins for AppicantIncome variable

# %%
bins=[0,2500,4000,6000,81000]
group=['Low','Average','High','Veryhigh']
train['Applicant_Income_bin']=pd.cut(train['ApplicantIncome'],bins=bins,labels=group)

# %%
Applicant_Income_bin=pd.crosstab(train['Applicant_Income_bin'],train['Loan_Status'])
Income_bin.div(Applicant_Income_bin.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %%
bins=[0,1000,3000,42000]
group=['Low','Average','High']
train['Coapplicant_Income_bin']=pd.cut(train['CoapplicantIncome'],bins=bins,labels=group)

# %%
Coapplicant_Income_bin=pd.crosstab(train['Coapplicant_Income_bin'],train['Loan_Status'])
Coapplicant_Income_bin.div(Coapplicant_Income_bin.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %% [markdown]
# It shows that if coapplicant’s income is less the chances of loan approval are high. But this does not look right. The possible reason behind this may be that most of the applicants don’t have any coapplicant so the coapplicant income for such applicants is 0 and hence the loan approval is not dependent on it. So we can make a new variable in which we will combine the applicant’s and coapplicant’s income to visualize the combined effect of income on loan approval.

# %%
train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome']

# %%
bins=[0,3000,4500,6000,81000]
group=['Low','Average','High','Veryhigh']
train['Total_Income_bin']=pd.cut(train['Total_Income'],bins=bins,labels=group)

# %%
Total_Income_bin=pd.crosstab(train['Total_Income_bin'],train['Loan_Status'])
Total_Income_bin.div(Total_Income_bin.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %%
bins=[0,100,200,700]
group=['Low','Average','High']
train['Loan_Amount_bins']=pd.cut(train['LoanAmount'],bins=bins,labels=group)

# %%
Loan_Amount_bins=pd.crosstab(train['Loan_Amount_bins'],train['Loan_Status'])
Loan_Amount_bins.div(Loan_Amount_bins.sum(1).astype(float),axis=0).plot.bar(stacked=True)

# %% [markdown]
#  proportion of approved loans is higher for Low and Average Loan Amount as compared to that of High Loan Amount which supports our hypothesis in which we considered that the chances of loan approval will be high when the loan amount is less.

# %%
train=train.drop(['Applicant_Income_bin','Coapplicant_Income_bin','Total_Income_bin','Loan_Amount_bins','Total_Income'],axis=1)

# %%
train['Dependents'].replace('3+',3,inplace=True)
test['Dependents'].replace('3+',3,inplace=True)
train['Loan_Status'].replace('N',0,inplace=True)
train['Loan_Status'].replace('Y',1,inplace=True)

# %% [markdown]
# # CORRELATION
#
#
# ![title](pearson.gif)
# r is the correlation
#
# Now lets look at the correlation between all the numerical variables. We will use the heat map to visualize the correlation.
#
# Heatmaps visualize data through variations in coloring. The variables with darker color means their correlation is more.

# %%
matrix=train.corr()
f,ax=plt.subplots(figsize=(9,6))
sea.heatmap(matrix,vmax=.8,square=True,cmap="BuPu")

# %% [markdown]
# We see that the most correlated variables are (ApplicantIncome - LoanAmount) and (Credit_History - Loan_Status).

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# For Null Value
#
# For numerical variables: imputation using mean or median
#
# For categorical variables: imputation using mode--------mode calculate frequency

# %%
import statistics

# %%
train['Gender'].fillna(statistics.mode(train['Gender']),inplace=True)
train['Married'].fillna(statistics.mode(train['Married']),inplace=True)
train['Dependents'].fillna(statistics.mode(train['Dependents']),inplace=True)
train['Self_Employed'].fillna(statistics.mode(train['Self_Employed']),inplace=True)
train['Credit_History'].fillna(statistics.mode(train['Credit_History']),inplace=True)

# %%
train['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %% [markdown]
# Actually the value of 360 repeating more

# %%
train['Loan_Amount_Term'].fillna(statistics.mode(train['Loan_Amount_Term']),inplace=True)

# %% [markdown]
#  we can use mean or median to impute the missing values. We will use median to fill the null values as earlier we saw that loan
#
#  amount have outliers so the mean will not be the proper approach as it is highly affected by the presence of outliers

# %%
train['LoanAmount'].fillna(train['LoanAmount'].median(),inplace=True)

# %%
train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test['Gender'].fillna(statistics.mode(test['Gender']),inplace=True)
test['Dependents'].fillna(statistics.mode(test['Dependents']),inplace=True)
test['Self_Employed'].fillna(statistics.mode(test['Self_Employed']),inplace=True)
test['Credit_History'].fillna(statistics.mode(test['Credit_History']),inplace=True)
test['Loan_Amount_Term'].fillna(statistics.mode(test['Loan_Amount_Term']),inplace=True)
test['LoanAmount'].fillna(test['LoanAmount'].median(),inplace=True)

# %% [markdown]
# Due to these outliers bulk of the data in the loan amount is at the left and the right tail is longer. This is called right skewness. One way to remove the skewness is by doing the log transformation. As we take the log transformation, it does not affect the smaller values much, but reduces the larger values. So, we get a distribution similar to normal distribution.
#
#  visualize the effect of log transformation

# %%
train['LoanAmount_log']=np.log(train['LoanAmount'])
train['LoanAmount_log'].hist(bins=20)
test['LoanAmount_log']=np.log(test['LoanAmount'])

# %%
train.drop('Loan_ID',axis=1,inplace=True)
test.drop('Loan_ID',axis=1,inplace=True)

# %%
x_train=train.drop('Loan_Status',1)

# %%
y=train['Loan_Status']

# %%
x_train=pd.get_dummies(x_train)
train=pd.get_dummies(train)
test=pd.get_dummies(test)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=1e-09,
#           verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(test)

# %%
submission=pd.read_csv('Sample_Submission_ZAuTl8O_FK3zQHh.csv')
submission['Loan_ID']=test_origional['Loan_ID']
submission['Loan_Status']=y_pred

# %%
submission['Loan_Status'].replace(0,'N',inplace=True)
submission['Loan_Status'].replace(1,'Y',inplace=True)

# %%
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('Logistic.csv',index=False)
